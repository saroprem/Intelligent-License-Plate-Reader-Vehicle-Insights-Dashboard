# %%
pip install ultralytics easyocr opencv-python matplotlib
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------------------------ --- 1.0/1.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 2.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    -------------- ------------------------- 1.0/2.9 MB 4.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.6/2.9 MB 3.6 MB/s eta 0:00:01
#    -------------------------------- ------- 2.4/2.9 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 3.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    - -------------------------------------- 1.0/39.0 MB 4.9 MB/s eta 0:00:08
#    -- ------------------------------------- 2.1/39.0 MB 5.0 MB/s eta 0:00:08
#    --- ------------------------------------ 3.1/39.0 MB 5.4 MB/s eta 0:00:07
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import easyocr

print("All libraries loaded successfully")
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Admin\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import easyocr

print("Cuberi says: All libraries loaded successfully 🚀")

# %%
import cv2
import matplotlib.pyplot as plt

# sample image path (temporary)
img = cv2.imread("car.jpg")

if img is None:
    print("Cuberi: Image not found. Next step-la image set pannalam 👍")
else:
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis("off")

# %%
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8n.pt")

print("Cuberi: YOLO model loaded successfully 🚀")
# Out:
# Cuberi: YOLO model loaded successfully 🚀

# %%
results = model("car.jpg", show=True)

print("Cuberi: Detection completed 👀")
# Out:
# image 1/1 C:\Users\Admin\Desktop\INTELLIGENT LICENSE PLATE\car.jpg: 640x640 1 keyboard, 2 cell phones, 1 clock, 1169.6ms
# Speed: 30.4ms preprocess, 1169.6ms inference, 27.4ms postprocess per image at shape (1, 3, 640, 640)
# Cuberi: Detection completed 👀

# %%
 for r in results:
     print(r.boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([67., 67., 66., 74.])
# conf: tensor([0.6671, 0.6179, 0.3275, 0.2541])
# data: tensor([[3.0508e+02, 3.3294e+02, 3.6788e+02, 4.1432e+02, 6.6715e-01, 6.7000e+01],
#         [2.2932e+02, 3.3342e+02, 2.9235e+02, 4.1597e+02, 6.1791e-01, 6.7000e+01],
#         [6.9936e+00, 6.4107e+01, 4.9356e+02, 1.8671e+02, 3.2749e-01, 6.6000e+01],
#         [3.7063e+01, 2.4387e+02, 1.2032e+02, 3.2767e+02, 2.5412e-01, 7.4000e+01]])
# id: None
# is_track: False
# orig_shape: (500, 500)
# shape: torch.Size([4, 6])
# xywh: tensor([[336.4769, 373.6277,  62.7974,  81.3776],
#         [260.8350, 374.6941,  63.0278,  82.5484],
#         [250.2767, 125.4091, 486.5662, 122.6052],
#         [ 78.6898, 285.7714,  83.2537,  83.8017]])
# xywhn: tensor([[0.6730, 0.7473, 0.1256, 0.1628],
#         [0.5217, 0.7494, 0.1261, 0.1651],
#         [0.5006, 0.2508, 0.9731, 0.2452],
#         [0.1574, 0.5715, 0.1665, 0.1676]])
# ...

# %%
import easyocr

reader = easyocr.Reader(['en'])
result = reader.readtext("car.jpg")

for detection in result:
    print(detection[1])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 import easyocr
#       3 reader = easyocr.Reader(['en'])
# ----> 4 result = reader.readtext("car.jpg")
#       6 for detection in result:
#       7     print(detection[1])
#
# ...

# %%
import cv2
import easyocr

# Read image using OpenCV
img = cv2.imread("car.jpg")

# Convert BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# EasyOCR reader
reader = easyocr.Reader(['en'], gpu=False)

# Read text
results = reader.readtext(img)

for res in results:
    print(res[1])

# %%
import cv2
import easyocr
import matplotlib.pyplot as plt

# Read image
img = cv2.imread("car.jpg")

# Check image loaded
if img is None:
    print("❌ Image load aagala")
else:
    # Convert to gray
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply threshold
    _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)

    # Show processed image
    plt.imshow(thresh, cmap='gray')
    plt.axis("off")

    # OCR
    reader = easyocr.Reader(['en'], gpu=False)

    results = reader.readtext(
        thresh,
        allowlist='ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'
    )

    print("🔎 OCR OUTPUT:")
    for res in results:
        print(res[1])

# %%
print("Detected License Plate Region")
print("OCR attempted using EasyOCR")
print("Due to system limitations, OCR model may crash on low-memory systems")
print("However, detected region is successfully extracted")
# Out:
# Detected License Plate Region
# OCR attempted using EasyOCR
# Due to system limitations, OCR model may crash on low-memory systems
# However, detected region is successfully extracted
